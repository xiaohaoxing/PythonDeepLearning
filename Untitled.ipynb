# %%
import matplotlib.pyplot as plt
from PIL import Image

url='/Users/haoxingxiao/Desktop/head.JPG'
image = Image.open(url)
plt.imshow(image)
plt.show()

# %%
image.getdata()

# %%
image.getdata().__dir__()
# Out:
# ['__len__',
#  '__getitem__',
#  'getpixel',
#  'putpixel',
#  'pixel_access',
#  'color_lut_3d',
#  'convert',
#  'convert2',
#  'convert_matrix',
#  'convert_transparent',
#  'copy',
#  'crop',
#  'expand',
#  'filter',
#  'histogram',
#  'entropy',
#  'modefilter',
#  'offset',
#  'paste',
#  'point',
#  'point_transform',
#  'putdata',
#  'quantize',
#  'rankfilter',
#  'resize',
#  'transpose',
#  'transform2',
#  'isblock',
#  'getbbox',
#  'getcolors',
#  'getextrema',
#  'getprojection',
#  'getband',
#  'putband',
#  'split',
#  'fillband',
#  'setmode',
#  'getpalette',
#  'getpalettemode',
#  'putpalette',
#  'putpalettealpha',
#  'putpalettealphas',
#  'chop_invert',
#  'chop_lighter',
#  'chop_darker',
#  'chop_difference',
#  'chop_multiply',
#  'chop_screen',
#  'chop_add',
#  'chop_subtract',
#  'chop_add_modulo',
#  'chop_subtract_modulo',
#  'chop_and',
#  'chop_or',
#  'chop_xor',
#  'gaussian_blur',
#  'unsharp_mask',
#  'box_blur',
#  'effect_spread',
# ...

# %%
image.getdata().size
# Out:
# (1161, 1080)
